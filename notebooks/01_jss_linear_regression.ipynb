# %% [markdown]
# # Model Representation

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# random data about houses
x_train = np.array([1.0, 2.0, 3.0, 3.5, 4.0, 6.5, 8.0])
y_train = np.array([300.0, 500.0, 730.0, 800.0, 950.0, 1300, 1900])

# %%
print(x_train)
print(y_train)

print(len(x_train))
print(len(y_train))
# Out:
# [1.  2.  3.  3.5 4.  6.5 8. ]
# [ 300.  500.  730.  800.  950. 1300. 1900.]
# 7
# 7

# %%
# Number of trainig example m, 2 ways

m = x_train.shape[0]
print(m)
m = len(x_train)
print(m)
# Out:
# 7
# 7

# %%
# Training examples
i = 0
x_i = x_train[i]
y_i = y_train[i]

print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
fig, ax = plt.subplots(figsize=(6,5))

ax.scatter(x_train, y_train, marker="x", color="red")

ax.set_title("Housing prices")
ax.set_xlabel("Size (1000 sqft)")
ax.set_ylabel("Price (K dollars)")

ax.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/5f/8wn5rtw909qbjlpmf_jgrh4h0000gn/T/ipykernel_8386/202030351.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot.
#
# Let's try to get a better intuition for this through the code blocks below. Let's start with $w = 100$ and $b = 100$.
#
# **Note: You can come back to this cell to adjust the model's w and b parameters**

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Now, let's compute the value of $f_{w,b}(x^{(i)})$ for your two data points. You can explicitly write this out for each data point as -
#
# for $x^{(0)}$, `f_wb = w * x[0] + b`
#
# for $x^{(1)}$, `f_wb = w * x[1] + b`
#
# For a large number of data points, this can get unwieldy and repetitive. So instead, you can calculate the function output in a `for` loop as shown in the `compute_model_output` function below.
# > **Note**: The argument description `(ndarray (m,))` describes a Numpy n-dimensional array of shape (m,). `(scalar)` describes an argument without dimensions, just a magnitude.
# > **Note**: `np.zero(n)` will return a one-dimensional numpy array with $n$ entries

# %%
def compute_model_function(x, w, b):

    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        print(f_wb)
    return f_wb

# %%
tmp_f_wb = compute_model_function(x_train, w, b)
print(tmp_f_wb)
# Out:
# [200.   0.   0.   0.   0.   0.   0.]
# [200. 300.   0.   0.   0.   0.   0.]
# [200. 300. 400.   0.   0.   0.   0.]
# [200. 300. 400. 450.   0.   0.   0.]
# [200. 300. 400. 450. 500.   0.   0.]
# [200. 300. 400. 450. 500. 750.   0.]
# [200. 300. 400. 450. 500. 750. 900.]
# [200. 300. 400. 450. 500. 750. 900.]

# %%
fig, ax = plt.subplots(figsize=(6,5))

ax.plot(x_train, tmp_f_wb, color="blue", label="our prediction")
ax.scatter(x_train, y_train, marker="x", color="red", label="actual values")

ax.set_title("Housing prices")
ax.set_xlabel("Size (1000 sqft)")
ax.set_ylabel("Price (K dollars)")

ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# w = 100 and b = 100 are not the right values

# %%
# change values manually, w= 200

w = 200
b = 100
print(f"w: {w}")
print(f"b: {b}")

tmp_f_wb = compute_model_function(x_train, w, b)
print(tmp_f_wb)

fig, ax = plt.subplots(figsize=(6,5))

ax.plot(x_train, tmp_f_wb, color="blue", label="our prediction")
ax.scatter(x_train, y_train, marker="x", color="red", label="actual values")

ax.set_title("Housing prices")
ax.set_xlabel("Size (1000 sqft)")
ax.set_ylabel("Price (K dollars)")

ax.legend()

plt.tight_layout()
plt.show()
# Out:
# w: 200
# b: 100
# [300.   0.   0.   0.   0.   0.   0.]
# [300. 500.   0.   0.   0.   0.   0.]
# [300. 500. 700.   0.   0.   0.   0.]
# [300. 500. 700. 800.   0.   0.   0.]
# [300. 500. 700. 800. 900.   0.   0.]
# [ 300.  500.  700.  800.  900. 1400.    0.]
# [ 300.  500.  700.  800.  900. 1400. 1700.]
# [ 300.  500.  700.  800.  900. 1400. 1700.]

# %% [markdown]
# Now we have a model

# %%
# prediction -> Predict a house 1200sqft, which means x_1 = 1.2


w = 200                         
b = 100    
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars
